# %% [markdown]
# # Satelite Images SIGPAC

# %% [markdown]
# In order to run the python script run the launch.sh file. The app will install all the dependencies needed you just need to make sure to have installed python 3.10 in your machine. After the execution these are the results the app will generate:

# %% [markdown]
# ## Original satelite image

# %% [markdown]
# This raster contains bands from 1 to 9 the band references are shown below:
#
#     1- Builtup (red)
#     2- Hervaceous Vegetation (yellow)
#     3- Shrubland (orange)
#     4- Water (blue)
#     5- Wetland (white blue)
#     6- Cropland (pink)
#     7- Open forest (white green)
#     8- Closed forest (dark green)
#     9- Baresoil (gray)
#
# ![title](/home/jesus/Documents/TFG/satelite_images_sigpac/assets/images/sat.png)

# %% [markdown]
# ## SIGPAC raster

# %% [markdown]
# This raster contains bands from 1 to 30 each band represent a use code from SIGPAC data:
#
#     1- Corrientes y superficies de agua (blue)
#     2- Viales (red)
#     3- Citricos-Frutal (pink)
#     4- Citricos (pink)
#     5- Citricos-Frutal de cascara (pink)
#     6- Citricos-Viñedo (pink)
#     7- Edificaciones (red)
#     8- Elemento del Paisaje (red)
#     9- Frutal de Cascara-Frutal (pink)
#     10- Frutal de Cascara-Olivar (pink)
#     11- Forestal (white green)
#     12- Frutal de Cascara (pink)
#     13- Frutal de Cascara-Viñedo (pink)
#     14- Frutal (pink)
#     15- Improductivo (gray)
#     16- Imvernadero y cultivos bajo plastico (white blue)
#     17- Olivar-Citricos (pink)
#     18- Olivar-Frutal (pink)
#     19- Olivar (pink)
#     20- Pasto Arbolado (orange)
#     21- Pasto Arbustivo (orange)
#     22- Pastizal (yellow)
#     23- Tierra Arable (pink)
#     24- Huerta (pink)
#     25- Frutal-Viñedo (pink)
#     26- Viñedo (pink)
#     27- Olivar-Viñedo (pink)
#     28- Zona Concentrada (red)
#     29- Zona Urbana (red)
#     30- Zona Censurada (red)
#
# ![title](/home/jesus/Documents/TFG/satelite_images_sigpac/assets/images/sgpc.png)

# %% [markdown]
# ## True/False shared pixels

# %% [markdown]
# The next raster shows the pixels in common.
#
# ![title](/home/jesus/Documents/TFG/satelite_images_sigpac/assets/images/redgreen.png)

# %% [markdown]
# ## Confusion Matrix raster

# %% [markdown]
# For this final raster we are now validating the model in four different classes so we can get a confusion matrix with the shared pixels.
#
#     1- True Positives (green)
#     2- False Positives (red)
#     3- False Negatives (blue)
#     4- True Negatives (gray)
#
# ![title](/home/jesus/Documents/TFG/satelite_images_sigpac/assets/images/conf.png)

# %% [markdown]
# ## Crop Metrics

# %%
import pandas as pd 

DIR = "../satelite_images_sigpac/csv/malaga_metrics.csv"

andalucia_csv = pd.read_csv(DIR)
andalucia_csv
# Out:
#                               Unnamed: 0  Aciertos   Fallos  \
# 0                        Citricos Frutal     55062    39882
# 1                               Citricos    652120   285683
# 2             Citricos-Frutal de cascara       434      762
# 3                        Citricos-Viñedo        77      197
# 4               Frutal de Cascara-Frutal       942     5860
# 5               Frutal de Cascara-Olivar     55860   140465
# 6                      Frutal de Cascara    520785  1169308
# 7               Frutal de Cascara-Viñedo       487     1310
# 8                                 Frutal   1279687  2557031
# 9   Invernadero y cultivos bajo plastico     11442    81995
# 10                       Olivar-Citricos      5530     5111
# 11                         Olivar-Frutal      9311    27102
# 12                                Olivar   7850621  5927193
# 13                         Tierra Arable   6908432  2169016
# 14                                Huerta    118231   119761
# ...

# %% [markdown]
# ![title](/home/jesus/Documents/TFG/satelite_images_sigpac/assets/images/img_aciertos_fallos.png)
