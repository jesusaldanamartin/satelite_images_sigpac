# %% [markdown]
# # Validation result

# %%
import pandas as pd
import numpy as np

DIR = "../satelite_images_sigpac/csv/"
DIR2 = "../satelite_images_sigpac/results/andalucia_hits_percentage.csv"

# %% [markdown]
# ## Andalucía Hits Percentage

# %%
andalucia_csv = pd.read_csv(DIR2)
andalucia_csv.head(20)
# Out:
#     Clase                                  Aciertos    Fallos     \
# 0   Citricos Frutal                             89403     979897
# 1   Citricos                                  5856071    2185685
# 2   Citricos-Frutal de cascara                   1545       7154
# 3   Citricos-Viñedo                           2950975       1059
# 4   Frutal de Cascara-Frutal                     7312     831503
# 5   Frutal de Cascara-Olivar                    82857     196400
# 6   Frutal de Cascara                         9080721   11096748
# 7   Frutal de Cascara-Viñedo                     3806       8630
# 8   Frutal                                    4774161    9937804
# 9   Imvernadero y cultivos bajo plastico       771053    4243997
# 10  Olivar-Citricos                             36820      73883
# 11  Olivar-Frutal                               30066      63609
# 12  Olivar                                   72449454   90171231
# ...

# %% [markdown]
# ## Cádiz

# %%
cadiz = pd.read_csv(DIR + "cadiz.csv")
cadiz = cadiz.transpose()
cadiz.head(20)
# Out:
#                                                0          1         2
# Unnamed: 0                                    TP         FN  Hit rate
# Citricos Frutal                           9461.0     4449.0  0.680158
# Citricos                                116030.0    62946.0  0.648299
# Citricos-Frutal de cascara                  42.0        1.0  0.976744
# Citricos-Viñedo                             18.0       15.0  0.545455
# Frutal de Cascara-Frutal                   153.0       33.0  0.822581
# Frutal de Cascara-Olivar                   113.0      180.0  0.385666
# Frutal de Cascara                        92409.0   118733.0  0.437663
# Frutal de Cascara-Viñedo                    62.0       31.0  0.666667
# Frutal                                  209724.0   190168.0  0.524452
# Imvernadero y cultivos bajo plastico      9600.0    50107.0  0.160785
# Olivar-Citricos                            524.0      331.0  0.612865
# ...

# %% [markdown]
# ## Córdoba

# %% [markdown]
# ## Granada
